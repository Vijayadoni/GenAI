# %%
# hugging face is like github for ai models and datasets.
# libraries: 
# huggingface_hub (lets you connect to hugging face from python for models and datasets) 
# datasets (lets you load datasets from hugging face easily)
# transformers (lets you load ai models from hugging face easily)
# peft (lets you do parameter efficient fine tuning on hugging face models)
# trl (lets you do reinforcement learning with hugging face models)
# accelerate (lets you train hugging face models on multiple gpus easily)
