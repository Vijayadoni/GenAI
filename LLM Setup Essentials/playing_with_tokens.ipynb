# %%
import tiktoken

def count_tokens(text: str, model: str = "gpt-4") -> int:
    """
    Count the number of tokens in a given text for a specified model.

    Args:
        text (str): The input text to be tokenized.
        model (str): The model name to determine the encoding. Default is "gpt-4".

    Returns:
        int: The number of tokens in the input text.
    """
    encoding = tiktoken.encoding_for_model(model)
    tokens = encoding.encode(text)
    return tokens

tmp2 = count_tokens("hello", "gpt2")
tmp3 = count_tokens("hello", "gpt-4")
print(tmp1)
print(tmp2)
print(tmp3)
# Out:
# [15339]
# [31373]
# [15339]

# %%
encoding = tiktoken.encoding_for_model("gpt-4")
# Out:
# <Encoding 'cl100k_base'>

# %%
encoding.decode(tmp2)
# Out:
# ' sooner'
